# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.preprocessing import LabelEncoder, PolynomialFeatures
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.ensemble import BaggingRegressor, GradientBoostingRegressor,  VotingRegressor, StackingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score, roc_auc_score
import warnings
# %matplotlib notebook

# %% [markdown]
# ## Load Data for cleaning and Exploration
# This project is aimed at predicting the Naira price of cars in Nigeria,
# Dataset from **Kaggle**

# %%
df = pd.read_csv('car_prices.csv')
df
# Out:
#                         car_id    price fuel type  gear type           Make  \
# 0     icwAaDOmX573WiRRnLFPT237  2812500    Petrol  Automatic         Toyota
# 1     ByZ3NlPy2x0arAIyrKazClUS  5000000    Petrol  Automatic          Acura
# 2     2zG6Mh3kwyoTvWoeKHkV1oFH  7592000    Petrol  Automatic          Acura
# 3     7APLHOPlI93qsYK0ST4D4wB2  9880000    Petrol  Automatic     Land Rover
# 4      zIrIDPJLd46eRQf9JFacc0e  4160000    Petrol  Automatic           Ford
# ...                        ...      ...       ...        ...            ...
# 3717  C4Ly76wwazrtbYRAWkTnv2Q5  1924000    Petrol  Automatic         Toyota
# 3718  jPA7XlJJxdwpZStlurumw59q  1890000    Petrol  Automatic  Mercedes-Benz
# 3719  g5szhuHeXu2djH1Z2be22G7E  1155000    Petrol  Automatic         Toyota
# 3720  mdZMNQK7Zez0cSS67Q9Quhzr  1260000    Petrol  Automatic         Toyota
# 3721  fSUvulLwnXYlc1muFsrjrsAR  1872000    Petrol  Automatic          Honda
#
#             Model  Year of manufacture  Colour      Condition   Mileage  \
# 0         Corolla                 2004  Silver  Nigerian Used  251732.0
# 1             MDX                 2007   Green   Foreign Used  224589.0
# 2              TL                 2012   White   Foreign Used  111334.0
# 3     Range Rover                 2012    Gray  Nigerian Used   72682.0
# 4            Edge                 2013    Gray  Nigerian Used   92118.0
# ...           ...                  ...     ...            ...       ...
# 3717         RAV4                 2003     Red  Nigerian Used  282769.0
# 3718      M Class                 2002  Silver  Nigerian Used  182544.0
# 3719        Camry                 2000   Black  Nigerian Used  234354.0
# 3720         RAV4                 2001   Black  Nigerian Used  345926.0
# 3721        Civic                 2007   Black  Nigerian Used   90330.0
#
#       Engine Size Selling Condition Bought Condition    car  \
# 0          1800.0        Registered       Registered    NaN
# 1          3700.0          Imported         Imported    SUV
# 2          3500.0          Imported         Imported  Sedan
# 3          4000.0        Registered         Imported    SUV
# 4          3500.0        Registered       Registered    SUV
# ...           ...               ...              ...    ...
# 3717       2000.0        Registered         Imported    SUV
# 3718       3200.0        Registered       Registered    SUV
# 3719       2200.0        Registered       Registered  Sedan
# 3720       2000.0        Registered       Registered    SUV
# 3721       1800.0        Registered       Registered    NaN
#
#                                Trim Drivetrain  Seats  Number of Cylinders  \
# 0                               NaN        NaN    NaN                  NaN
# 1                               NaN        NaN    NaN                  NaN
# 2     SH-AWD Automatic Tech Package  All Wheel    5.0                  6.0
# 3                               NaN        NaN    NaN                  NaN
# 4                               NaN        NaN    NaN                  NaN
# ...                             ...        ...    ...                  ...
# 3717                      Automatic  All Wheel    5.0                  4.0
# 3718                         ML 320  All Wheel    5.0                  6.0
# 3719    LE 4dr Sedan (2.2L 4cyl 4A)      Front    5.0                  4.0
# 3720                            NaN        NaN    NaN                  NaN
# 3721                            NaN        NaN    NaN                  NaN
#
#       Horse Power Registered city
# 0             NaN             NaN
# 1             NaN             NaN
# 2           309.0             NaN
# 3             NaN             NaN
# 4             NaN           Lagos
# ...           ...             ...
# 3717          NaN         Plateau
# 3718        215.0             NaN
# 3719        136.0          RIVERS
# 3720          NaN             NaN
# 3721          NaN             NaN
#
# [3722 rows x 20 columns]

# %%
df.isnull().sum()
# Out:
# car_id                    0
# price                     0
# fuel type                 1
# gear type                 2
# Make                      0
# Model                     0
# Year of manufacture       0
# Colour                    5
# Condition                 0
# Mileage                  59
# Engine Size              61
# Selling Condition         0
# Bought Condition          0
# car                    1955
# Trim                   2843
# Drivetrain             2884
# Seats                  2934
# Number of Cylinders    2896
# Horse Power            2967
# Registered city        1821
# dtype: int64

# %%
df.columns
# Out:
# Index(['car_id', 'price', 'fuel type', 'gear type', 'Make', 'Model',
#        'Year of manufacture', 'Colour', 'Condition', 'Mileage', 'Engine Size',
#        'Selling Condition', 'Bought Condition', 'car', 'Trim', 'Drivetrain',
#        'Seats', 'Number of Cylinders', 'Horse Power', 'Registered city'],
#       dtype='object')

# %%
null_columns = ['car_id','car', 'Trim', 'Drivetrain', 'Seats', 'Number of Cylinders', 'Horse Power', 'Registered city']

# %%
df = df.drop(columns=null_columns)
df
# Out:
#         price fuel type  gear type           Make        Model  \
# 0     2812500    Petrol  Automatic         Toyota      Corolla
# 1     5000000    Petrol  Automatic          Acura          MDX
# 2     7592000    Petrol  Automatic          Acura           TL
# 3     9880000    Petrol  Automatic     Land Rover  Range Rover
# 4     4160000    Petrol  Automatic           Ford         Edge
# ...       ...       ...        ...            ...          ...
# 3717  1924000    Petrol  Automatic         Toyota         RAV4
# 3718  1890000    Petrol  Automatic  Mercedes-Benz      M Class
# 3719  1155000    Petrol  Automatic         Toyota        Camry
# 3720  1260000    Petrol  Automatic         Toyota         RAV4
# 3721  1872000    Petrol  Automatic          Honda        Civic
#
#       Year of manufacture  Colour      Condition   Mileage  Engine Size  \
# 0                    2004  Silver  Nigerian Used  251732.0       1800.0
# 1                    2007   Green   Foreign Used  224589.0       3700.0
# 2                    2012   White   Foreign Used  111334.0       3500.0
# 3                    2012    Gray  Nigerian Used   72682.0       4000.0
# 4                    2013    Gray  Nigerian Used   92118.0       3500.0
# ...                   ...     ...            ...       ...          ...
# 3717                 2003     Red  Nigerian Used  282769.0       2000.0
# 3718                 2002  Silver  Nigerian Used  182544.0       3200.0
# 3719                 2000   Black  Nigerian Used  234354.0       2200.0
# 3720                 2001   Black  Nigerian Used  345926.0       2000.0
# 3721                 2007   Black  Nigerian Used   90330.0       1800.0
#
#      Selling Condition Bought Condition
# 0           Registered       Registered
# 1             Imported         Imported
# 2             Imported         Imported
# 3           Registered         Imported
# 4           Registered       Registered
# ...                ...              ...
# 3717        Registered         Imported
# 3718        Registered       Registered
# 3719        Registered       Registered
# 3720        Registered       Registered
# 3721        Registered       Registered
#
# [3722 rows x 12 columns]

# %%
df = df.dropna()
df
# Out:
#         price fuel type  gear type           Make        Model  \
# 0     2812500    Petrol  Automatic         Toyota      Corolla
# 1     5000000    Petrol  Automatic          Acura          MDX
# 2     7592000    Petrol  Automatic          Acura           TL
# 3     9880000    Petrol  Automatic     Land Rover  Range Rover
# 4     4160000    Petrol  Automatic           Ford         Edge
# ...       ...       ...        ...            ...          ...
# 3717  1924000    Petrol  Automatic         Toyota         RAV4
# 3718  1890000    Petrol  Automatic  Mercedes-Benz      M Class
# 3719  1155000    Petrol  Automatic         Toyota        Camry
# 3720  1260000    Petrol  Automatic         Toyota         RAV4
# 3721  1872000    Petrol  Automatic          Honda        Civic
#
#       Year of manufacture  Colour      Condition   Mileage  Engine Size  \
# 0                    2004  Silver  Nigerian Used  251732.0       1800.0
# 1                    2007   Green   Foreign Used  224589.0       3700.0
# 2                    2012   White   Foreign Used  111334.0       3500.0
# 3                    2012    Gray  Nigerian Used   72682.0       4000.0
# 4                    2013    Gray  Nigerian Used   92118.0       3500.0
# ...                   ...     ...            ...       ...          ...
# 3717                 2003     Red  Nigerian Used  282769.0       2000.0
# 3718                 2002  Silver  Nigerian Used  182544.0       3200.0
# 3719                 2000   Black  Nigerian Used  234354.0       2200.0
# 3720                 2001   Black  Nigerian Used  345926.0       2000.0
# 3721                 2007   Black  Nigerian Used   90330.0       1800.0
#
#      Selling Condition Bought Condition
# 0           Registered       Registered
# 1             Imported         Imported
# 2             Imported         Imported
# 3           Registered         Imported
# 4           Registered       Registered
# ...                ...              ...
# 3717        Registered         Imported
# 3718        Registered       Registered
# 3719        Registered       Registered
# 3720        Registered       Registered
# 3721        Registered       Registered
#
# [3600 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# price                  0
# fuel type              0
# gear type              0
# Make                   0
# Model                  0
# Year of manufacture    0
# Colour                 0
# Condition              0
# Mileage                0
# Engine Size            0
# Selling Condition      0
# Bought Condition       0
# dtype: int64

# %%
df.describe()
# Out:
#               price  Year of manufacture       Mileage   Engine Size
# count  3.600000e+03          3600.000000  3.600000e+03  3.600000e+03
# mean   4.540438e+06          2008.163889  1.952695e+05  1.120777e+04
# std    4.342391e+06             4.211461  1.402830e+05  1.100276e+05
# min    5.500000e+05          1979.000000  1.000000e+00  1.800000e+02
# 25%    2.340000e+06          2006.000000  1.177440e+05  2.000000e+03
# 50%    3.360000e+06          2008.000000  1.761190e+05  2.500000e+03
# 75%    5.040000e+06          2011.000000  2.454910e+05  3.500000e+03
# max    6.240000e+07          2022.000000  2.456318e+06  3.500000e+06

# %%
sns.set_style('whitegrid')
fig, axs = plt.subplots(2,3, figsize = (15,12))
sns.countplot(ax = axs[0,0], y='Make', palette='coolwarm', data=df)
sns.boxplot(ax = axs[0,1], x='Engine Size', palette='coolwarm', data=df)
sns.boxplot(ax = axs[0,2], x='price', palette='coolwarm', data=df)
sns.countplot(ax = axs[1,0], x=df[df['Make'] == "Toyota"].Model, palette='coolwarm')
sns.countplot(ax = axs[1,1], x='Condition', palette='coolwarm', data=df)
sns.countplot(ax = axs[1,2], x='gear type', palette='coolwarm', data=df)
# axs[0,0].tick_params(axis="x", rotation=90)
axs[1,0].tick_params(axis="x", rotation=90)
# axs[1,0].x_label("Toyota Models")
fig.suptitle('Little Visualization of the Important Columns')
# Out:
# Text(0.5, 0.98, 'Little Visualization of the Important Columns')

# %% [markdown]
# ## From the Visualization above
# It is clare that data is insufficient to predict price of all vehicles. Therefore, this model will only predict
# price of Toyota cars since it has a significant amoun of data avilable for it.

# %%
df = df[df['Make'] == "Toyota"]
df
# Out:
#          price fuel type  gear type    Make    Model  Year of manufacture  \
# 0      2812500    Petrol  Automatic  Toyota  Corolla                 2004
# 8      3885000    Petrol  Automatic  Toyota    Camry                 2007
# 10     3432000    Petrol  Automatic  Toyota    Camry                 2011
# 15     9135000    Petrol  Automatic  Toyota    HiAce                 2011
# 17    13520000    Petrol  Automatic  Toyota    Camry                 2018
# ...        ...       ...        ...     ...      ...                  ...
# 3707   2100000    Petrol  Automatic  Toyota    Camry                 2008
# 3709   1690000    Petrol  Automatic  Toyota  Corolla                 2003
# 3717   1924000    Petrol  Automatic  Toyota     RAV4                 2003
# 3719   1155000    Petrol  Automatic  Toyota    Camry                 2000
# 3720   1260000    Petrol  Automatic  Toyota     RAV4                 2001
#
#       Colour      Condition   Mileage  Engine Size Selling Condition  \
# 0     Silver  Nigerian Used  251732.0       1800.0        Registered
# 8       Gold   Foreign Used  159726.0       3000.0          Imported
# 10     Black  Nigerian Used  128048.0       2500.0        Registered
# 15    Silver   Foreign Used   31234.0       2700.0          Imported
# 17     Black  Nigerian Used   68871.0       3500.0        Registered
# ...      ...            ...       ...          ...               ...
# 3707   Black  Nigerian Used  121483.0       2400.0        Registered
# 3709     Red  Nigerian Used  253425.0       1800.0        Registered
# 3717     Red  Nigerian Used  282769.0       2000.0        Registered
# 3719   Black  Nigerian Used  234354.0       2200.0        Registered
# 3720   Black  Nigerian Used  345926.0       2000.0        Registered
#
#      Bought Condition
# 0          Registered
# 8            Imported
# 10           Imported
# 15           Imported
# 17           Imported
# ...               ...
# 3707       Registered
# 3709       Registered
# 3717         Imported
# 3719       Registered
# 3720       Registered
#
# [1565 rows x 12 columns]

# %%
df = df[df['Engine Size']<0.5e6]

# %%
sns.set_style('whitegrid')
fig, axs = plt.subplots(3,3, figsize = (15,18))
sns.countplot(ax = axs[0,0], y='Model', palette='coolwarm', data=df)
sns.boxplot(ax = axs[0,1], x='Engine Size', palette='coolwarm', data=df)
sns.boxplot(ax = axs[0,2], x='price', palette='coolwarm', data=df)
sns.countplot(ax = axs[1,0], x='Year of manufacture', palette='coolwarm', data=df)
sns.countplot(ax = axs[1,1], x='Condition', palette='coolwarm', data=df)
sns.countplot(ax = axs[1,2], x='gear type', palette='coolwarm', data=df)
sns.countplot(ax = axs[2,0], x='Selling Condition', palette='coolwarm', data=df)
sns.countplot(ax = axs[2,1], x='Bought Condition', palette='coolwarm', data=df)
df.groupby('Colour').size().plot(kind='pie', colors=sns.color_palette('bright'), ax = axs[2,2])
axs[0,1].tick_params(axis="x", rotation=90)
axs[1,0].tick_params(axis="x", rotation=90)
# axs[1,0].x_label("Toyota Models"), autopct='%.2f'
fig.suptitle('Little Visualization of the key columns')
# Out:
# Text(0.5, 0.98, 'Little Visualization of the key columns')

# %%
sns.set_style('dark')
plt.figure()
# g =sns.relplot(x='Engine Size', y='price', data=df, kind='line', row='Year of manufacture')
g =sns.relplot(x='Engine Size', y='price', data=df, kind='scatter', size=1)
g.fig.suptitle('Relationship between Engine size and Price of cars', y = 1.01)
# Out:
# Text(0.5, 1.01, 'Relationship between Engine size and Price of cars')

# %%
sns.set_style('dark')
plt.figure()
# g =sns.relplot(x='Engine Size', y='price', data=df, kind='line', col='Model', row='Year of manufacture')
g =sns.relplot(x='Mileage', y='price', data=df, kind='scatter', size=1)
g.fig.suptitle('Relationship between Milage and Price of cars', y = 1.01)
# Out:
# Text(0.5, 1.01, 'Relationship between Milage and Price of cars')

# %%
le = LabelEncoder()

# %%
df.columns
# Out:
# Index(['price', 'fuel type', 'gear type', 'Make', 'Model',
#        'Year of manufacture', 'Colour', 'Condition', 'Mileage', 'Engine Size',
#        'Selling Condition', 'Bought Condition'],
#       dtype='object')

# %%
df['fuel_type_label'] = le.fit_transform(df['fuel type'])
df['gear_type_label'] = le.fit_transform(df['gear type'])
df['Make_label'] = le.fit_transform(df['Make'])
df['Model_label'] = le.fit_transform(df['Model'])
df['Year of manufacture_label'] = le.fit_transform(df['Year of manufacture'])
df['Colour_label'] = le.fit_transform(df['Colour'])
df['Condition_label'] = le.fit_transform(df['Condition'])
df['Selling Condition_label'] = le.fit_transform(df['Selling Condition'])
df['Bought Condition_label'] = le.fit_transform(df['Bought Condition'])
df

# %%
lookup_fuel_type = dict(zip(df.fuel_type_label.unique(), df['fuel type'].unique()))
lookup_gear_type = dict(zip(df.gear_type_label.unique(), df['gear type'].unique()))
lookup_Model = dict(zip(df['Model_label'].unique(), df['Model'].unique())) 
lookup_Year_of_manufacture = dict(zip(df['Year of manufacture_label'].unique(), df['Year of manufacture'].unique()))
lookup_Make = dict(zip(df.Make_label.unique(), df.Make.unique()))
lookup_Colour = dict(zip(df.Colour_label.unique(), df.Colour.unique())) 
lookup_Condition = dict(zip(df.Condition_label.unique(), df.Condition.unique()))
lookup_Selling_Condition = dict(zip(df['Selling Condition_label'].unique(), df['Selling Condition'].unique()))
lookup_Bought_Condition = dict(zip(df['Bought Condition_label'].unique(), df['Bought Condition'].unique()))
lookup_Bought_Condition
# Out:
# {2: 'Registered', 1: 'Imported', 0: 'Brand new'}

# %%
columns_to_drop = ['fuel type', 'gear type', 'Make', 'Model', 'Year of manufacture', 'Colour', 'Condition', 'Selling Condition', 'Bought Condition']

# %%
df = df.drop(columns=columns_to_drop)
df
# Out:
#          price   Mileage  Engine Size  fuel_type_label  gear_type_label  \
# 0      2812500  251732.0       1800.0                3                0
# 8      3885000  159726.0       3000.0                3                0
# 10     3432000  128048.0       2500.0                3                0
# 15     9135000   31234.0       2700.0                3                0
# 17    13520000   68871.0       3500.0                3                0
# ...        ...       ...          ...              ...              ...
# 3707   2100000  121483.0       2400.0                3                0
# 3709   1690000  253425.0       1800.0                3                0
# 3717   1924000  282769.0       2000.0                3                0
# 3719   1155000  234354.0       2200.0                3                0
# 3720   1260000  345926.0       2000.0                3                0
#
#       Make_label  Model_label  Year of manufacture_label  Colour_label  \
# 0              0            8                         10            13
# 8              0            5                         13             5
# 10             0            5                         17             1
# 15             0           13                         17            13
# 17             0            5                         24             1
# ...          ...          ...                        ...           ...
# 3707           0            5                         14             1
# 3709           0            8                          9            12
# 3717           0           22                          9            12
# 3719           0            5                          6             1
# 3720           0           22                          7             1
#
#       Condition_label  Selling Condition_label  Bought Condition_label
# 0                   2                        2                       2
# 8                   1                        1                       1
# 10                  2                        2                       1
# 15                  1                        1                       1
# 17                  2                        2                       1
# ...               ...                      ...                     ...
# 3707                2                        2                       2
# 3709                2                        2                       2
# 3717                2                        2                       1
# 3719                2                        2                       2
# 3720                2                        2                       2
#
# [1560 rows x 12 columns]

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True).set_title('Correlation among the variables')
# Out:
# Text(0.5, 1.0, 'Correlation among the variables')

# %%
X = df.drop(columns=['price']).values
X
# Out:
# array([[2.51732e+05, 1.80000e+03, 3.00000e+00, ..., 2.00000e+00,
#         2.00000e+00, 2.00000e+00],
#        [1.59726e+05, 3.00000e+03, 3.00000e+00, ..., 1.00000e+00,
#         1.00000e+00, 1.00000e+00],
#        [1.28048e+05, 2.50000e+03, 3.00000e+00, ..., 2.00000e+00,
#         2.00000e+00, 1.00000e+00],
#        ...,
#        [2.82769e+05, 2.00000e+03, 3.00000e+00, ..., 2.00000e+00,
#         2.00000e+00, 1.00000e+00],
#        [2.34354e+05, 2.20000e+03, 3.00000e+00, ..., 2.00000e+00,
#         2.00000e+00, 2.00000e+00],
#        [3.45926e+05, 2.00000e+03, 3.00000e+00, ..., 2.00000e+00,
#         2.00000e+00, 2.00000e+00]])

# %%
y = df[['price']].values
y
# Out:
# array([[2812500],
#        [3885000],
#        [3432000],
#        ...,
#        [1924000],
#        [1155000],
#        [1260000]], dtype=int64)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.25, random_state = 0)

# %% [markdown]
# ## Design Goal
# This model is mainly interested in accuracy, hence the model eveluation is based on its accuracy.

# %% [markdown]
# ### Select optimal hyperparameters to give best accuracy for the selected models

# %%
models = [

    DecisionTreeRegressor(),
#     RandomForestRegressor(),
    ExtraTreesRegressor(),
    KNeighborsRegressor()
]

# %%
model_hyperparameters = {
    'dec_tree_hyp' : {
#         'n_estimators' : [2, 4, 6, 8, 10],
        'max_depth' : [2,4,6,8,10]
    },
    'extra_forest_hyp' : {
        'n_estimators' : [2, 4, 6, 8, 10],
        'max_depth' : [8,10,15,20]
    },
    'KNN_hyp' : {
        'n_neighbors' : [10, 20, 30]
    }
}

# %%
model_keys= list(model_hyperparameters.keys())
print(model_keys)
# Out:
# ['dec_tree_hyp', 'extra_forest_hyp', 'KNN_hyp']

# %%
def model_selection(list_of_models,hyperparametrs_dictionary):
    
    result = []
    i = 0
    
    for model in list_of_models:
        key = model_keys[i]
        params = hyperparametrs_dictionary[key]
        i+=1
        
        print(model)
        print(params)
        print('---------------------------------------------')
        
        classifier = GridSearchCV(model, params, cv=5, scoring='r2')
        
        # fitting the data to classifier
        
        classifier.fit(X,y.ravel())
        result.append({
            'model used': model,
            'highest score' : classifier.best_score_,
            'best hyperparameters': classifier.best_params_
        })
        
    result_dataframe = pd.DataFrame(result, columns=['model used', 'highest score', 'best hyperparameters'])

    return result_dataframe

# %%
model_selection(models, model_hyperparameters)
# Out:
# DecisionTreeRegressor()
# {'max_depth': [2, 4, 6, 8, 10]}
# ---------------------------------------------
# ExtraTreesRegressor()
# {'n_estimators': [2, 4, 6, 8, 10], 'max_depth': [8, 10, 15, 20]}
# ---------------------------------------------
# KNeighborsRegressor()
# {'n_neighbors': [10, 20, 30]}
# ---------------------------------------------
#                 model used  highest score  \
# 0  DecisionTreeRegressor()       0.575459
# 1    ExtraTreesRegressor()       0.625486
# 2    KNeighborsRegressor()      -0.054626
#
#                    best hyperparameters
# 0                      {'max_depth': 6}
# 1  {'max_depth': 10, 'n_estimators': 8}
# 2                   {'n_neighbors': 20}

# %% [markdown]
# ### Using DecisionTreeRegressor

# %%
dtr = DecisionTreeRegressor(max_depth = 10)

# %% [markdown]
# #### Using GridSearchCV to improve decision tree generalization ability

# %%
grid_values = {'max_depth': [5, 6, 8, 10]}

# %%
grid_clf_acc = GridSearchCV(dtr, param_grid = grid_values)
grid_clf_acc.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeRegressor(max_depth=10),
#              param_grid={'max_depth': [5, 6, 8, 10]})

# %%
print('Grid best parameter (max. accuracy): ', grid_clf_acc.best_params_)
print('Grid best score (accuracy): ', grid_clf_acc.best_score_)
# Out:
# Grid best parameter (max. accuracy):  {'max_depth': 5}
# Grid best score (accuracy):  0.5949783829234467

# %%
# alternative metric to optimize over grid parameters: R2_score
grid_clf_r2 = GridSearchCV(dtr, param_grid = grid_values, scoring = 'r2')
grid_clf_r2.fit(X_train, y_train)
y_decision_fn_scores_auc = grid_clf_r2.predict(X_test)

# %%
print('Grid best parameter (max. r2): ', grid_clf_r2.best_params_)
print('Grid best score (r2): ', grid_clf_r2.best_score_)
# Out:
# Grid best parameter (max. r2):  {'max_depth': 6}
# Grid best score (r2):  0.5034584593878183

# %%
print('R-squared test score: {:.3f}'
     .format(grid_clf_r2.score(X_test, y_test)))
# Out:
# R-squared test score: 0.682

# %%
print('R-squared test score: {:.3f}'
     .format(grid_clf_r2.score(X_train, y_train)))
# Out:
# R-squared test score: 0.873

# %% [markdown]
# #### Using decision tree directly

# %%
dtr.fit(X_train, y_train.ravel())
# Out:
# DecisionTreeRegressor(max_depth=10)

# %%
dtr_pred = dtr.predict(X_test)

# %%
print('R-squared test score: {:.3f}'
     .format(dtr.score(X_test, y_test)))
# Out:
# R-squared test score: 0.838

# %%
print('R-squared test score: {:.3f}'
     .format(dtr.score(X_train, y_train)))
# Out:
# R-squared test score: 0.983

# %% [markdown]
# ## Using ExtraTreesRegressor

# %%
etr = ExtraTreesRegressor(max_depth=10, n_estimators=8).fit(X_train, y_train.ravel())

# %%
etr_pred = etr.predict(X_test)

# %%
print('R-squared test score: {:.3f}'
     .format(etr.score(X_test, y_test)))
# Out:
# R-squared test score: 0.821

# %%
print('R-squared test score: {:.3f}'
     .format(etr.score(X_train, y_train)))
# Out:
# R-squared test score: 0.976
